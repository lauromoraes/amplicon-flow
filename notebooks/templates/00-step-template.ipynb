# %% [markdown]
# # Step N — Analysis name
#
# ## 1. Objective
#
# State the biological and analytical objective.
#
# ## 2. Scientific background
#
# Summarize the method and cite primary literature.
#
# ## 3. Methodological rationale
#
# Explain why the method and parameterization are appropriate.

# %% [markdown]
# ## 4. Inputs
#
# Describe expected artifacts/files and their provenance.

# %% [markdown]
# ## 5. Parameters
#
# The following is the only Papermill parameter cell.

# %%
experiment_name = "example-study"
base_dir = "."
threads = 8
replace_files = False

# %% [markdown]
# ## 6. Computational provenance

# %%
from pathlib import Path
import os, sys
PROJECT_DIR=Path(base_dir).expanduser().resolve()
EXPERIMENT_DIR=PROJECT_DIR/"experiments"/experiment_name
print("Python:",sys.version.split()[0])
print("Experiment:",experiment_name)
print("QIIME cache:",os.getenv("QIIME_CACHE"))

# %% [markdown]
# ## 7. Analysis
#
# Keep scientific method calls visible here.

# %%
# Scientific analysis code goes here.

# %% [markdown]
# ## 8. Results and quality-control assessment
#
# Define diagnostics and acceptance criteria.

# %% [markdown]
# ## 9. Interpretation

# %% [markdown]
# ## 10. Outputs

# %% [markdown]
# ## 11. Limitations

# %% [markdown]
# ## 12. References
#
# List primary scientific references.
